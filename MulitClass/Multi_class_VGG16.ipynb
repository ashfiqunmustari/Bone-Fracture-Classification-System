# %%
# !pip install tensorflow-io
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.30.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.30.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-io) (0.30.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.30.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (23.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %%
###
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import glob
import shutil
import pathlib
import random

#model selection
from sklearn.model_selection import train_test_split

#data augumentation
import  cv2
import imgaug
import imageio
from imgaug import augmenters as iaa

##
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from keras.applications import ResNet50
from keras.layers import Dense, GlobalMaxPool2D, BatchNormalization, Dropout
from keras.models import Model, Sequential
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# from google.colab import drive
# drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !unzip /content/drive/MyDrive/BoneFractureWork/Multiclass/OurDataset.zip

# %%
Path= "/gdrive/MyDrive/BoneFractureWork/OurDataset/"
Path = pathlib.Path(Path)
Path
# Out:
# PosixPath('/gdrive/MyDrive/BoneFractureWork/OurDataset')

# %%
# FracturedElbow = list(Path.glob('Elbow/Positive/*/*.png'))
# NonFracturedElbow = list(Path.glob('Elbow/Negative/*/*.png'))
# FracturedFinger = list(Path.glob('Finger/Positive/*/*.png'))
# NonFracturedFinger = list(Path.glob('Finger/Negative/*/*.png'))
# FracturedForearm = list(Path.glob('Forearm/Positive/*/*.png'))
# NonFracturedForearm = list(Path.glob('Forearm/Negative/*/*.png'))
# FracturedHand = list(Path.glob('Hand/Positive/*/*.png'))
# NonFracturedHand= list(Path.glob('Hand/Negative/*/*.png'))
# FracturedHumerus= list(Path.glob('Humerus/Positive/*/*.png'))
# NonFracturedHumerus = list(Path.glob('Humerus/Negative/*/*.png'))
# FracturedShoulder = list(Path.glob('Shoulder/Positive/*/*.png'))
# NonFracturedShoulder = list(Path.glob('Shoulder/Negative/*/*.png'))
# FracturedWrist = list(Path.glob('Wrist/Positive/*/*.png'))
# NonFracturedWrist = list(Path.glob('Wrist/Negative/*/*.png'))

# boneFracture= [FracturedElbow, NonFracturedElbow, FracturedFinger, NonFracturedFinger, FracturedForearm, NonFracturedForearm, FracturedHand, 
#          NonFracturedHand, FracturedHumerus, NonFracturedHumerus, FracturedShoulder, NonFracturedShoulder, FracturedWrist, NonFracturedWrist]
# boneFracture_classes = ['FracturedElbow', 'NonFracturedElbow', 'FracturedFinger', 'NonFracturedFinger', 'FracturedForearm', 'NonFracturedForearm', 'FracturedHand', 
#          'NonFracturedHand', 'FracturedHumerus', 'NonFracturedHumerus', 'FracturedShoulder', 'NonFracturedShoulder', 'FracturedWrist', 'NonFracturedWrist']

# print(boneFracture_classes)

# %%
Path= "/content/OurDataset/"
Path = pathlib.Path(Path)
image_count = len(list(Path.glob('*/*/*/*.png')))

print(f'Total images: {image_count}')
print(f'Total number of classes: {len(boneFracture_classes)}')
count = 0
boneFracture_count = []
for x in boneFracture_classes:
  print(f'Total {x} images: {len(boneFracture[count])}')
  boneFracture_count.append(len(boneFracture[count]))
  count += 1

sns.set_style('darkgrid')
plt.figure(figsize=(20,8))
sns.barplot(x=boneFracture_classes, y=boneFracture_count, palette="Blues_d")
plt.show()
# Out:
# Total images: 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4027b25dd6d1> in <module>
#       4
#       5 print(f'Total images: {image_count}')
# ----> 6 print(f'Total number of classes: {len(boneFracture_classes)}')
#       7 count = 0
#       8 boneFracture_count = []
#
# NameError: name 'boneFracture_classes' is not defined

# %%
# # function
# import  cv2
# import imgaug
# import imageio
# import os
# import numpy as np
# from imgaug import augmenters as iaa

# class DataAugmentation:
# 	def __init__(self, root_dir="",output_dir=""):
# 		self.root_dir = root_dir
# 		self.output_dir = output_dir
# 		print("Instance of the DataAugmentation class created")

# 	def augmentation_of_image(self, test_image, output_path):
# 		self.test_image = test_image;
# 		self.output_path = output_path;
# 		#define the Augmenters

# 		#properties: A range of values signifies that one of these numbers is randmoly chosen for every augmentation for every batch

# 		# Apply affine transformations to each image.
# 		rotate = iaa.Affine(rotate=(-90,90));  
# 		scale = iaa.Affine(scale={"x": (0.5, 0.9), "y": (0.5,0.9)}); 
# 		translation = iaa.Affine(translate_percent={"x": (-0.15, 0.15), "y": (-0.15, 0.15)});
# 		shear = iaa.Affine(shear=(-2, 2)); #plagio parallhlogrammo wihthin a range (-8,8)
# 		zoom = iaa.PerspectiveTransform(scale=(0.01, 0.15), keep_size=True) # do not change the output size of the image
# 		h_flip = iaa.Fliplr(1.0); # flip horizontally all images (100%)
# 		v_flip = iaa.Flipud(1.0); #flip vertically all images
# 		padding=iaa.KeepSizeByResize(iaa.CropAndPad(percent=(0.05, 0.25)))#positive values correspond to padding 5%-25% of the image,but keeping the origial output size of the new image


# 		#More augmentations
# 		blur = iaa.GaussianBlur(sigma=(0, 1.22)) # blur images with a sigma 0-2,a number ofthis range is randomly chosen everytime.Low values suggested for this application
# 		contrast = iaa.contrast.LinearContrast((0.75, 1.5)); #change the contrast by a factor of 0.75 and 1.5 sampled randomly per image
# 		contrast_channels = iaa.LinearContrast((0.75, 1.5), per_channel=True) #and for 50% of all images also independently per channel:
# 		sharpen = iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)); #sharpen with an alpha from 0(no sharpening) - 1(full sharpening) and change the lightness form 0.75 to 1.5 
# 		gauss_noise = iaa.AdditiveGaussianNoise(scale=0.111*255, per_channel=True) #some random gaussian noise might occur in cell images,especially when image quality is poor
# 		laplace_noise = iaa.AdditiveLaplaceNoise(scale=(0, 0.111*255)) #we choose to be in a small range, as it is logical for training the cell images


# 		#Brightness 
# 		brightness = iaa.Multiply((0.35,1.65)) #change brightness between 35% or 165% of the original image
# 		brightness_channels = iaa.Multiply((0.5, 1.5), per_channel=0.75) # change birghtness for 25% of images.For the remaining 75%, change it, but also channel-wise.

# 		#CHANNELS (RGB)=(Red,Green,Blue)
# 		red =iaa.WithChannels(0, iaa.Add((10, 100))) #increase each Red-pixels value within the range 10-100
# 		red_rot = iaa.WithChannels(0,iaa.Affine(rotate=(0, 45))) #rotate each image's red channel by 0-45 degrees
# 		green= iaa.WithChannels(1, iaa.Add((10, 100)))#increase each Green-pixels value within the range 10-100
# 		green_rot=iaa.WithChannels(1,iaa.Affine(rotate=(0, 45))) #rotate each image's green channel by 0-45 degrees
# 		blue=iaa.WithChannels(2, iaa.Add((10, 100)))#increase each Blue-pixels value within the range 10-100
# 		blue_rot=iaa.WithChannels(2,iaa.Affine(rotate=(0, 45))) #rotate each image's blue channel by 0-45 degrees

# 		#colors
# 		channel_shuffle =iaa.ChannelShuffle(1.0); #shuffle all images of the batch
# 		grayscale = iaa.Grayscale(1.0)
# 		hue_n_saturation = iaa.MultiplyHueAndSaturation((0.5, 1.5), per_channel=True) #change hue and saturation with this range of values for different values 
# 		add_hue_saturation = iaa.AddToHueAndSaturation((-50, 50), per_channel=True) #add more hue and saturation to its pixels
# 		#Quantize colors using k-Means clustering
# 		kmeans_color = iaa.KMeansColorQuantization(n_colors=(4, 16)) #quantizes to k means 4 to 16 colors (randomly chosen). Quantizes colors up to 16 colors

# 		#Alpha Blending 
# 		blend =iaa.AlphaElementwise((0, 1.0), iaa.Grayscale((0,1.0))) ; #blend depending on which value is greater

# 		#Contrast augmentors
# 		clahe = iaa.CLAHE(tile_grid_size_px=((3, 21),[0,2,3,4,5,6,7])) #create a clahe contrast augmentor H=(3,21) and W=(0,7)
# 		histogram = iaa.HistogramEqualization() #performs histogram equalization

# 		#Augmentation list of metadata augmentors
# 		OneofRed = iaa.OneOf( [red]);
# 		OneofGreen = iaa.OneOf( [green] );
# 		OneofBlue = iaa.OneOf( [blue]);
# 		contrast_n_shit = iaa.OneOf([contrast, brightness, brightness_channels]);
# 		SomeAug = iaa.SomeOf(2,[rotate,scale, translation, shear, h_flip,v_flip],random_order=True);
# 		SomeClahe = iaa.SomeOf(2, [clahe, iaa.CLAHE(clip_limit=(1, 10)),iaa.CLAHE(tile_grid_size_px=(3, 21)),iaa.GammaContrast((0.5, 2.0)), iaa.AllChannelsCLAHE() , iaa.AllChannelsCLAHE(clip_limit=(1, 10), per_channel=True)],random_order=True) #Random selection from clahe augmentors
# 		edgedetection= iaa.OneOf([iaa.EdgeDetect(alpha=(0, 0.7)),iaa.DirectedEdgeDetect(alpha=(0, 0.7), direction=(0.0, 1.0))]);# Search in some images either for all edges or for directed edges.These edges are then marked in a black and white image and overlayed with the original image using an alpha of 0 to 0.7.
# 		canny_filter = iaa.OneOf([iaa.Canny(), iaa.Canny(alpha=(0.5, 1.0), sobel_kernel_size=[3, 7])]); #choose one of the 2 canny filter options
# 		OneofNoise = iaa.OneOf([blur, gauss_noise, laplace_noise])
# 		Color_1 = iaa.OneOf([channel_shuffle,grayscale, hue_n_saturation , add_hue_saturation, kmeans_color]);
# 		Color_2 = iaa.OneOf([channel_shuffle,grayscale, hue_n_saturation , add_hue_saturation, kmeans_color]);
# 		Flip = iaa.OneOf([histogram , v_flip, h_flip]);

# 		#Define the augmentors used in the DA
# 		Augmentors= [SomeAug, SomeClahe, edgedetection, canny_filter, Color_1, contrast_n_shit]


# 		for i in range(0,6):
# 			img = cv2.imread(test_image) #read you image
# 			images = np.array([img for _ in range(6)], dtype=np.uint8)  # 12 is the size of the array that will hold 8 different images
# 			images_aug = Augmentors[i].augment_images(images)  #alternate between the different augmentors for a test image
# 			cv2.imwrite(os.path.join(output_path,test_image +"new"+str(i)+'.png'), images_aug[i])  #write all changed images

# %%
# import shutil
# class DataAugmentation_Extension:
#     def __init__(self, directory=""):
#       self.directory = directory
#       print("Instance of DataAugmentation_Extension class created")
#     def printnow(self, dir):
#       pass
#       # print("Just testing that the method calling is working "+ dir)
    
#     def extend_dataset(self, directory):
#       # print("HEY")
#       library_augment= DataAugmentation();
#       self.directory = directory 

#       if not os.path.exists(self.directory):
#         print("ERROR! Couldn't find directory!")
#       else:
#         print("Directory exists")
#       class_path = directory
#       class_files = [class_path+name for name in os.listdir(class_path)]
#       # print(class_files) #call augmentation for all class_files
#       for i in range(len(class_files)):
#         library_augment.augmentation_of_image(class_files[i], class_path)

# %%
# def augment_data(Bone, Type):
#   Sets = ["Train", "Valid", "Test"]
#   for Set in Sets: 
#     target_directory = "/content/OurDataset/"+Bone+"/"+Type+"/"+Set+"/"
#     #create an instance of the class
#     datasetda = DataAugmentation_Extension()
#     datasetda.extend_dataset(target_directory)

# %%
# augment_data("Forearm", "Positive")
# augment_data("Humerus", "Positive")
# augment_data("Humerus", "Negative")

# %%
def different(bone, which_set):

  P = list()
  N = list()
  Pos_dir = "/gdrive/MyDrive/BoneFractureWork/OurDataset/"+bone+"/Positive/"+which_set+"/"
  Neg_dir = "/gdrive/MyDrive/BoneFractureWork/OurDataset/"+bone+"/Negative/"+which_set+"/"

  P.extend([Pos_dir+path, "Fractured "+bone] for path in os.listdir(Pos_dir))
  N.extend([Neg_dir+path, "Non-fractured "+bone] for path in os.listdir(Neg_dir))
  
  return P,N

# %%
def Set_creation(which_set):  

  print(f"{which_set}:----")
  Elbow_P, Elbow_N = different("Elbow", which_set)
  print(f"Elbow P: {len(Elbow_P)}, N: {len(Elbow_N)}")
  Finger_P, Finger_N = different("Finger", which_set)
  print(f"Finger P: {len(Finger_P)}, N: {len(Finger_N)}")
  Forearm_P, Forearm_N = different("Forearm", which_set)
  print(f"Forearm P: {len(Forearm_P)}, N: {len(Forearm_N)}")
  Hand_P, Hand_N = different("Hand", which_set)
  print(f"Hand P: {len(Hand_P)}, N: {len(Hand_N)}")
  Humerus_P, Humerus_N = different("Humerus", which_set)
  print(f"Humerus P: {len(Humerus_P)}, N: {len(Humerus_N)}")
  Shoulder_P, Shoulder_N = different("Shoulder", which_set)
  print(f"Shoulder P: {len(Shoulder_P)}, N: {len(Shoulder_N)}")
  Wrist_P, Wrist_N = different("Wrist", which_set)
  print(f"Wrist P: {len(Wrist_P)}, N: {len(Wrist_N)}")

  # Bones = ["Elbow", "Finger", "Forearm", "Hand", "Humerus", "Shoulder", "Wrist"]

  IMAGES_AND_LABELS = []

  IMAGES_AND_LABELS.extend(batch for batch in Elbow_P)
  IMAGES_AND_LABELS.extend(batch for batch in Elbow_N)

  IMAGES_AND_LABELS.extend(batch for batch in Finger_P)
  IMAGES_AND_LABELS.extend(batch for batch in Finger_N)

  IMAGES_AND_LABELS.extend(batch for batch in Forearm_P)
  IMAGES_AND_LABELS.extend(batch for batch in Forearm_N)

  IMAGES_AND_LABELS.extend(batch for batch in Hand_P)
  IMAGES_AND_LABELS.extend(batch for batch in Hand_N)

  IMAGES_AND_LABELS.extend(batch for batch in Humerus_P)
  IMAGES_AND_LABELS.extend(batch for batch in Humerus_N)

  IMAGES_AND_LABELS.extend(batch for batch in Shoulder_P)
  IMAGES_AND_LABELS.extend(batch for batch in Shoulder_N)

  IMAGES_AND_LABELS.extend(batch for batch in Wrist_P)
  IMAGES_AND_LABELS.extend(batch for batch in Wrist_N)

  return IMAGES_AND_LABELS

# %%
# print(len(os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/")))
# Out:
# 20475

# %%
# Elbow_P, Elbow_N = different("Finger","Train")

# %%
TRAIN_IMAGES_AND_LABELS = Set_creation("Train")
VALID_IMAGES_AND_LABELS = Set_creation("Valid")
print(len(TRAIN_IMAGES_AND_LABELS))
print(len(VALID_IMAGES_AND_LABELS))
# Out:
# Train:----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-9-e7d1ba3710eb> in <module>
# ----> 1 TRAIN_IMAGES_AND_LABELS = Set_creation("Train")
#       2 VALID_IMAGES_AND_LABELS = Set_creation("Valid")
#       3 print(len(TRAIN_IMAGES_AND_LABELS))
#
# <ipython-input-7-537cc846e3cf> in Set_creation(which_set)
#       3   print(f"{which_set}:----")
# ----> 4   Elbow_P, Elbow_N = different("Elbow", which_set)
#       5   print(f"Elbow P: {len(Elbow_P)}, N: {len(Elbow_N)}")
#
# <ipython-input-6-800c71211bc5> in different(bone, which_set)
#       8   P.extend([Pos_dir+path, "Fractured "+bone] for path in os.listdir(Pos_dir))
# ----> 9   N.extend([Neg_dir+path, "Non-fractured "+bone] for path in os.listdir(Neg_dir))
#      10
#
# OSError: [Errno 5] Input/output error: '/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
# Elbow_P = []
# Elbow_P.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Positive/Train/"+path, "Fractured Elbow"] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Positive/Train/"))
# Elbow_N = []
# Elbow_N.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/"+path, "Non-Fractured Elbow"] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/"))

# Finger_P = []
# Finger_P.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset/Finger/Positive/Train/"+path, "Fractured Finger"] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Finger/Positive/Train/"))
# Finger_N = []
# Finger_N.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset/Finger/Negative/Train/"+path, "Non-Fractured Finger"] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Finger/Negative/Train/"))


# _P = []
# _P.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset//Positive/Train/"+path, "Fractured "] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset//Positive/Train/"))
# _N = []
# _N.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset//Negative/Train/"+path, "Non-Fractured "] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset//Negative/Train/"))

# Finger_P  = []
# Finger_N = []

# Finger_P  = []
# Finger_N = []

# Finger_P  = []
# Finger_N = []

# Finger_P  = []
# Finger_N = []

# Humerus_P  = []
# Humerus_N = []

# Shoulder_P  = []
# Shoulder_N = []

# Wrist_P  = []
# Wrist_N = []

# %%
# Elbow_P.extend(["/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/"+path, "Fractured Elbow"] for path in os.listdir("/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/"))
# Out:
# [['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2612.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2612.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2612.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2612.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2392.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2391.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1346.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2393.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1348.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2394.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1660.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2282.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1250.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2283.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2395.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1249.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1659.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1257.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1256.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1258.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1759.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1758.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1757.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1307.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1306.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1305.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2452.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2451.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2469.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2470.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2471.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2453.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2924.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2489.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2490.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1521.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2923.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1520.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2412.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2413.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2414.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2411.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2548.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2551.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2410.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2550.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2549.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2147.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2146.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2196.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2197.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2485.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1529.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2198.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1528.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2486.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1964.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1963.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1965.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1421.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1422.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1420.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2488.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2487.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2591.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2593.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2592.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1841.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1840.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1842.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1497.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1495.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1493.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1494.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1969.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1966.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1967.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1967.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1967.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1967.pngnew3.png',
#   'Fractured Elbow'],
# ...
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2690.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2690.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2689.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1681.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1682.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1683.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2265.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2264.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2115.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2900.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2116.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2902.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2899.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2901.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2768.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2770.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2769.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2724.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2723.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2725.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/2375.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1959.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1958.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1333.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1335.pngnew5.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew0.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew1.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew2.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew3.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew4.png',
#   'Fractured Elbow'],
#  ['/gdrive/MyDrive/BoneFractureWork/OurDataset/Elbow/Negative/Train/1334.pngnew5.png',
#   'Fractured Elbow'],
#  ...]

# %%
TRAIN_IMAGES_AND_LABELS = TRAIN_IMAGES_AND_LABELS+VALID_IMAGES_AND_LABELS
len(TRAIN_IMAGES_AND_LABELS)
# Out:
# 54237

# %%
# sample_img = cv2.imread('/content/OurDataset/Elbow/Negative/Test/0.png')
# plt.imshow(sample_img)
# print(f'Image dimensions: {sample_img.shape}')

# %%
# import numpy as np
# import glob
# from keras.layers import Dense, BatchNormalization, Dropout
# from keras.preprocessing.image import ImageDataGenerator
# from keras.models import Model, Sequential
# from keras.optimizers import Adam
# from keras.callbacks import EarlyStopping

# from sklearn.metrics import accuracy_score, confusion_matrix, classification_report




# """LOADING Dataset"""
# # path to folder with data
# Path = "/content/OurDataset/"
# Path = pathlib.Path(Path)
# trainPath= Path.glob("*/*/Train/")
# print(len(list(trainPath)))
# no_DA_IDG = ImageDataGenerator()

# training_set = no_DA_IDG.flow_from_directory(trainPath,
#                                                 target_size=(-1,28,28,1), # typical imagenet dimensions
#                                                 color_mode='rgb',
#                                                 batch_size=32,
#                                                 class_mode='categorical', shuffle=True)



# validation_set = no_DA_IDG.flow_from_directory(path.glob("*/*/Valid/"),
#                                                 target_size=(-1,28,28,1),
#                                                 color_mode='rgb',
#                                                 class_mode='categorical',
#                                                 shuffle=True)



# test_set = no_DA_IDG.flow_from_directory(path.glob("*/*/Test/"),
#                                                 target_size=(224,224),
#                                                 color_mode='rgb',
#                                                 batch_size=1,
#                                                 class_mode='categorical',
#                                                 shuffle=False)

# %%
# import random
# tf.random.set_seed(67)
# # Shuffling the lists.
# random.shuffle(TRAIN_IMAGES_AND_LABELS)
# random.shuffle(VALID_IMAGES_AND_LABELS)
# random.shuffle(TEST_IMAGES_AND_LABELS)

# %%
TRAIN_IMAGES = []
TRAIN_LABELS = []

for i in range(len(TRAIN_IMAGES_AND_LABELS)):
  TRAIN_IMAGES.append(TRAIN_IMAGES_AND_LABELS[i][0])
  TRAIN_LABELS.append(TRAIN_IMAGES_AND_LABELS[i][1])

# VALID_IMAGES = []
# VALID_LABELS = []

# for i in range(len(VALID_IMAGES_AND_LABELS)):
#   VALID_IMAGES.append(VALID_IMAGES_AND_LABELS[i][0])
#   VALID_LABELS.append(VALID_IMAGES_AND_LABELS[i][1])

# TEST_IMAGES = []
# TEST_LABELS = []

# for i in range(len(TEST_IMAGES_AND_LABELS)):
#   TEST_IMAGES.append(TEST_IMAGES_AND_LABELS[i][0])
#   TEST_LABELS.append(TEST_IMAGES_AND_LABELS[i][1])

# %%
# TRAIN_LABELS

# %%
from sklearn import preprocessing

La_encoder = preprocessing.LabelEncoder()

La_encoder.fit(TRAIN_LABELS)
TRAIN_OHC_LABELS = La_encoder.transform(TRAIN_LABELS)
TRAIN_OHC_LABELS = np.reshape(TRAIN_OHC_LABELS, (TRAIN_OHC_LABELS.size, 1))

# La_encoder.fit(VALID_LABELS)
# VALID_OHC_LABELS = La_encoder.transform(VALID_LABELS)
# VALID_OHC_LABELS = np.reshape(VALID_OHC_LABELS, (VALID_OHC_LABELS.size, 1))

# La_encoder.fit(TEST_LABELS)
# TEST_OHC_LABELS = La_encoder.transform(TEST_LABELS)
# TEST_OHC_LABELS = np.reshape(TEST_OHC_LABELS, (TEST_OHC_LABELS.size, 1))

# %%
# TRAIN_OHC_LABELS

# %%
def color_jitter(x, strength=[0.4, 0.4, 0.4, 0.1]):
    x = tf.image.random_brightness(x, max_delta=0.8 * strength[0])
    x = tf.image.random_contrast(
        x, lower=1 - 0.8 * strength[1], upper=1 + 0.8 * strength[1]
    )
    x = tf.image.random_saturation(
        x, lower=1 - 0.8 * strength[2], upper=1 + 0.8 * strength[2]
    )
    x = tf.image.random_hue(x, max_delta=0.2 * strength[3])
    # Affine transformations can disturb the natural range of
    # RGB images, hence this is needed.
    x = tf.clip_by_value(x, 0, 255)
    return x

def color_drop(x):
    x = tf.image.rgb_to_grayscale(x)
    x = tf.tile(x, [1, 1, 3])
    return x


def random_apply(func, x, p):
    if tf.random.uniform([], minval=0, maxval=1) < p:
        return func(x)
    else:
        return x

# %%
IMG_SIZE = 224

NUMBER_OF_CHANNELS = 3

INPUT_SHAPE = [IMG_SIZE, IMG_SIZE, 3]

OUTPUT_SHAPE = len(La_encoder.classes_)

LR = 0.0001

BATCH_SIZE = 64

Labels = La_encoder.classes_

EPOCHS = 30

# %%
TRAIN_BOOL_LABELS = []
for i in range(len(TRAIN_LABELS)):
  TRAIN_BOOL_LABELS.append(La_encoder.classes_ == np.array(TRAIN_LABELS[i]))

# VALID_BOOL_LABELS = []
# for i in range(len(VALID_LABELS)):
#   VALID_BOOL_LABELS.append(La_encoder.classes_ == np.array(VALID_LABELS[i]))

# TEST_BOOL_LABELS = []
# for i in range(len(TEST_LABELS)):
#   TEST_BOOL_LABELS.append(La_encoder.classes_ == np.array(TEST_LABELS[i]))

# %%
def Normal_preprocess(filepath):
  
  image = tf.io.read_file(filepath)
  image = tf.io.decode_png(image, channels=3)
  image = tf.image.convert_image_dtype(image, tf.float32)
  image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])

  return image

# %%
def preprocess_image(filepath):
  
  image = tf.io.read_file(filepath)
  image = tf.io.decode_png(image, channels=3)
  image = random_apply(color_jitter, image, p=0.8)
  image = random_apply(color_drop, image, p=0.2)
  image = tf.image.convert_image_dtype(image, tf.float32)
  image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])

  return image

# %%
def get_augment_image_and_label(X, Y):
  
  image = preprocess_image(X)
  label = Y

  return image, label

# %%
def get_image_and_label(X, Y):
  
  image = Normal_preprocess(X)
  label = Y

  return image, label

# %%
TRAIN_BOOL_LABELS

# %%
from sklearn.model_selection import train_test_split

X_train, X_val_test, Y_train, Y_val_test = train_test_split(TRAIN_IMAGES, TRAIN_BOOL_LABELS, train_size = 0.9, shuffle=True, random_state = 53, stratify=TRAIN_BOOL_LABELS)

X_val, X_test, Y_val, Y_test = train_test_split(X_val_test, Y_val_test, train_size = 0.2, shuffle=True, random_state = 53)

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (48813, 1084, 4340)

# %%
def create_databatches(X, Y=None, test_data = False, cross_train = False,val_data = False, batch_size=BATCH_SIZE):

  if test_data:
    print("Creation of test databatches..")
    data = tf.data.Dataset.from_tensor_slices((tf.constant(X)))
    data_batch = data.map(Normal_preprocess).batch(batch_size)
  
  elif val_data or cross_train:
    if val_data: 
      print("Creation of valid databatches..")
    else:
      print("Creation of cross entropy databatches..")
    data = tf.data.Dataset.from_tensor_slices((tf.constant(X), tf.constant(Y)))
    data = data.shuffle(buffer_size = len(X))
    data_batch = data.map(get_image_and_label).batch(batch_size)
  
  else:
    print("Creation of train databatches..")
    data = tf.data.Dataset.from_tensor_slices((tf.constant(X), tf.constant(Y)))
    data = data.shuffle(buffer_size = len(X))
    data_batch = data.map(get_augment_image_and_label).batch(batch_size)
  
  return data_batch

# %%
train_ds = create_databatches(X_train, Y_train)
val_ds = create_databatches(X_val, Y_val, val_data = True)
test_ds = create_databatches(X_test, Y_test, test_data = True)
# Out:
# Creation of train databatches..
# Creation of valid databatches..
# Creation of test databatches..

# %%
INPUT_SHAPE = [IMG_SIZE, IMG_SIZE, 3]

Labels = La_encoder.classes_

OUTPUT_SHAPE = len(Labels)

suffix = "VGG-16" 

num_epochs = 50

# %% [markdown]
# **VGG16**

# %%
import numpy as np
from keras.layers import Dense, GlobalMaxPool2D, BatchNormalization, Dropout
from keras.applications import VGG16
from keras.models import Model, Sequential

base_model = VGG16(input_shape=(224,224,3), input_tensor=None,
                                                include_top=False, 
                                                weights='imagenet')
# for i, layer in enumerate(base_model.layers):
#    print(i, layer.name)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
import numpy as np
from keras.layers import Dense, GlobalMaxPool2D, BatchNormalization, Dropout,GlobalAveragePooling2D
from keras.models import Model, Sequential
from keras import applications

def VGG(seed = 666):
    np.random.seed(seed)
    vgg16 = VGG16(weights="imagenet", include_top=False)
    for layer in vgg16.layers[:13]:
        layer.trainable = False
    for layer in vgg16.layers[13:]:
        layer.trainable = True
    y = (vgg16.get_layer("block4_conv3")).output
    mx_y = GlobalMaxPool2D()(y)
    x = BatchNormalization()(mx_y)
    x = Dropout(.5)(x)
    x = Dense(1024, activation='relu', name="dense_1024")(x)
    x = BatchNormalization()(x)
    x = Dropout(.5)(x)
    preds = Dense(14,activation='softmax')(x)
    model = Model(inputs=vgg16.input, outputs=preds)
    return model

# %%
model_vgg16= VGG()

epochs = 10
opt = Adam(learning_rate=1e-4)
model_vgg16.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
import keras.utils
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.activations import selu

checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/BoneFractureWork/Multiclass/SavedModels/VGG_16_stratify_2.hdf5', 
                               monitor='val_accuracy', mode='max',
                               verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=2, min_lr=1e-5)
callbacks=[early_stopping, reduce_lr, checkpointer]

# %%
from sklearn.utils import class_weight

Y_train1 = TRAIN_OHC_LABELS

yy_train = Y_train1[:,0]

class_weights = dict(zip(np.unique(yy_train), class_weight.compute_class_weight('balanced', classes = np.unique(yy_train),
                                        y = yy_train)))

# %%
# historyvgg16 = model_vgg16.fit(train_ds , epochs = 50,validation_data = val_ds, callbacks=callbacks, class_weight=class_weights)

# %%
# FilePath = "/content/drive/MyDrive/BoneFractureWork/Multiclass/SavedModels/VGG_16.hdf5"
# model_vgg16 = tf.keras.models.load_model(filepath = FilePath)

# %%
predictions = model_vgg16.predict(test_ds)
# Out:
# 68/68 [==============================] - 28s 403ms/step

# %%
def get_labels(Predictions):

  pred = []
  true = []

  for i in range(len(Predictions)):
    pred.append(Labels[Predictions[i].argmax()])
    true.append(Labels[Y_test[i].argmax()])
  
  return pred, true

# %%
Y_pred, Y_true = get_labels(predictions)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(Y_true, Y_pred) * 100
print(f"Accuracy: {Accuracy:.2f}%\n")
# Out:
# Accuracy: 81.36%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

c_m = confusion_matrix(Y_true, Y_pred)
print(c_m)

# Cm_Df = pd.DataFrame(c_m, index = Labels, columns = Labels)

# fig, ax = plt.subplots(figsize = (25,25))

# ax = sns.heatmap(
#     Cm_Df,
#     cbar = False, 
#     cmap = "gnuplot",
#     annot = True,
#     linewidth = 3,
#     annot_kws = {
#         'fontsize' : 20
#     }
# )

# plt.suptitle(f"Confusion matrix for VGG16", fontsize=20)
# plt.suptitle(f"VGG16", fontsize=15, color = 'purple',fontweight="bold")
# plt.xlabel("Actual Values", fontsize=15)
# plt.ylabel("Predicted Values", fontsize=15)
# plt.show()
# Out:
# [[100   0   1   0   2   0   0  76   0   0   0   2   0   0]
#  [  0 135   0   0   0   0   1   0  44   0   0   0   0   0]
#  [  0   0 425   0  13   0   0   3   1   7   0   4   0   0]
#  [  0   3   0  41   0   1   1   0   1   0  89   0   0   1]
#  [  0   0   8   0 373   2   0   1   0   0   0  34   1   0]
#  [  0   0   0   0   3 228   0   1   0   0   0   4 131   0]
#  [  0   1   5   1   1   0 246   0   0   0   0   0   0  93]
#  [ 17   0   2   0   0   0   1 223   1   2   0   3   2   0]
#  [  0  42   0   0   0   0   0   0 222   0   7   0   0   1]
#  [  0   0  18   0   0   0   0   4   0  87   0   0   0   1]
#  [  0   0   0  13   0   0   0   0   1   0 327   0   0   0]
#  [  0   0   3   0  45   2   0   1   0   2   0 401   0   0]
#  [  0   0   0   0   1  49   0   0   0   0   0   5 299   0]
#  [  0   0   1   4   0   0  38   0   3   0   4   0   0 424]]

# %%
from sklearn.metrics import classification_report
c_r = classification_report(Y_true, Y_pred)
print(f"classification report: \n")
print(f"{c_r}")

# %%
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.utils.scores import CategoricalScore

# %%
def plotcall(x, y, label):
  plt.gcf().set_size_inches(12, 12)
  plt.title(f"{x}\n{y} label: {label}", color = 'red', fontdict = {"fontsize" : 15} )
  plt.tight_layout()

# %%
from matplotlib import cm

def Ex_AI(O_im, XAI, true, pred, x_model, alp=0.5):
  rows=1
  columns = 2
  fig = plt.figure(figsize=(15,7))
  fig.add_subplot(rows, columns, 1)
  plt.imshow(O_im)
  plotcall('Original image', 'True', true)
  fig.add_subplot(rows, columns, 2)
  heat_map = np.uint8(cm.jet(tf.squeeze(XAI))[...,:3]*255)
  plt.imshow(O_im)
  plt.imshow(heat_map, cmap='plasma', alpha=alp)
  plotcall( x_model+' visualization', 'Predicted', pred)
  plt.show()

# %%
from tf_keras_vis.gradcam import Gradcam

replace2linear = ReplaceToLinear()

# The class value of the image will be passed to the categorical score 
score = CategoricalScore(0)

X = "A image path will be passed"

gradcam = Gradcam(model_vgg16,
                  model_modifier=replace2linear,
                  clone=True)

grad_cam = gradcam(score, X, penultimate_layer=-1)

# %%
Ex_AI(X, grad_cam, "Original label", "Predicted label", 'Grad-CAM')

# %%
# model_path = os.path.join("/content/drive/MyDrive/BoneFractureWork/Multiclass/SavedModels/model_vgg16.hdf5")

# model_dir = model_path

# classifierCS = tf.keras.models.load_model(filepath = model_dir)

# %%
# Y_train1=TRAIN_OHC_LABELS

# %%
# yy_train = Y_train1[:,0]

# %%
# from sklearn.utils import class_weight

# class_weights = dict(zip(np.unique(yy_train), class_weight.compute_class_weight('balanced', classes = np.unique(yy_train),
#                                         y = yy_train))) 

# class_weights

# %%
# model_vgg16= VGG()

# epochs = 50
# opt = Adam(learning_rate=1e-3)
# classifierCS.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# import tensorflow as tf
# import keras.utils
# from keras.callbacks import ModelCheckpoint
# from keras.optimizers import Adam
# import numpy as np
# import os
# from keras.preprocessing.image import ImageDataGenerator
# from keras.callbacks import ReduceLROnPlateau,EarlyStopping
# from keras.activations import selu

# checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/BoneFractureWork/Multiclass/SavedModels/modelCS_vgg16.hdf5', 
#                                monitor='val_accuracy', mode='max',
#                                verbose=1, save_best_only=True)
# early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=2, min_lr=1e-5)
# callbacks=[early_stopping, reduce_lr, checkpointer]

# %%
# classifierCS.fit(train_ds , epochs = 50,validation_data = val_ds, callbacks=callbacks,class_weight=class_weights)

# %%
# FilePath = "/content/drive/MyDrive/BoneFractureWork/Multiclass/SavedModels/modelCS_vgg16.hdf5"
# classifier1 = tf.keras.models.load_model(filepath = FilePath)

# %%
# predictions1 = classifier1.predict(test_ds)
# Out:
# 126/126 [==============================] - 39s 305ms/step

# %%
# def get_labels(Predictions):

#   pred = []
#   true = []

#   for i in range(len(Predictions)):
#     pred.append(Labels[Predictions[i].argmax()])
#     true.append(Labels[TEST_BOOL_LABELS[i].argmax()])
  
#   return pred, true

# %%
Y_pred, Y_true = get_labels(predictions1)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(Y_true, Y_pred) * 100
print(f"Accuracy: {Accuracy:.2f}%\n")
# Out:
# Accuracy: 65.01%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

c_m = confusion_matrix(Y_true, Y_pred)

Cm_Df = pd.DataFrame(c_m, index = Labels, columns = Labels)

fig, ax = plt.subplots(figsize = (25,25))

ax = sns.heatmap(
    Cm_Df,
    cbar = False,
    cmap = "gnuplot",
    annot = True,
    linewidth = 3,
    annot_kws = {
        'fontsize' : 20
    }
)

plt.suptitle(f"Confusion matrix for VGG16", fontsize=20)
plt.suptitle(f"VGG16", fontsize=15, color = 'purple',fontweight="bold")
plt.xlabel("Actual Values", fontsize=15)
plt.ylabel("Predicted Values", fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report
c_r = classification_report(Y_true, Y_pred)
print(f"classification report: \n")
print(f"{c_r}")
# Out:
# classification report:
#
#                         precision    recall  f1-score   support
#
#        Fractured Elbow       0.64      0.61      0.63       574
#       Fractured Finger       0.69      0.74      0.71       574
#      Fractured Forearm       0.80      0.45      0.58       574
#         Fractured Hand       0.63      0.57      0.60       574
#      Fractured Humerus       0.77      0.18      0.30       574
#     Fractured Shoulder       0.64      0.50      0.56       574
#        Fractured Wrist       0.78      0.66      0.72       574
#    Non-fractured Elbow       0.63      0.79      0.70       574
#   Non-fractured Finger       0.72      0.67      0.69       574
#  Non-fractured Forearm       0.60      0.86      0.71       574
#     Non-fractured Hand       0.61      0.68      0.64       574
#  Non-fractured Humerus       0.55      0.73      0.63       574
# Non-fractured Shoulder       0.59      0.83      0.69       574
#    Non-fractured Wrist       0.70      0.82      0.76       574
#
#               accuracy                           0.65      8036
#              macro avg       0.67      0.65      0.64      8036
#           weighted avg       0.67      0.65      0.64      8036

# %% [markdown]
# **Contrastive Learning**

# %%
#Layer Batch Normalization
class UnitNormLayer(tf.keras.layers.Layer):
    '''Normalize vectors (euclidean norm) in batch to unit hypersphere.
    '''
    def __init__(self):
        super(UnitNormLayer, self).__init__()

    def call(self, input_tensor):
        norm = tf.norm(input_tensor, axis=1)
        return input_tensor / tf.reshape(norm, [-1, 1])

# %%
def pdist_euclidean(A):
    # Euclidean pdist
    # https://stackoverflow.com/questions/37009647/compute-pairwise-distance-in-a-batch-without-replicating-tensor-in-tensorflow
    r = tf.reduce_sum(A*A, 1)

    # turn r into column vector
    r = tf.reshape(r, [-1, 1])
    D = r - 2*tf.matmul(A, tf.transpose(A)) + tf.transpose(r)
    return tf.sqrt(D)


def square_to_vec(D):
    '''Convert a squared form pdist matrix to vector form.
    '''
    n = D.shape[0]
    triu_idx = np.triu_indices(n, k=1)
    d_vec = tf.gather_nd(D, list(zip(triu_idx[0], triu_idx[1])))
    return d_vec


def get_contrast_batch_labels(y):
    '''
    Make contrast labels by taking all the pairwise in y
    y: tensor with shape: (batch_size, )
    returns:   
        tensor with shape: (batch_size * (batch_size-1) // 2, )
    '''
    y_col_vec = tf.reshape(tf.cast(y, tf.float32), [-1, 1])
    D_y = pdist_euclidean(y_col_vec)
    d_y = square_to_vec(D_y)
    y_contrasts = tf.cast(d_y == 0, tf.int32)
    return y_contrasts


def get_contrast_batch_labels_regression(y):
    '''
    Make contrast labels for regression by taking all the pairwise in y
    y: tensor with shape: (batch_size, )
    returns:   
        tensor with shape: (batch_size * (batch_size-1) // 2, )
    '''
    raise NotImplementedError


def max_margin_contrastive_loss(z, y, margin=1.0, metric='euclidean'):
    '''
    Wrapper for the maximum margin contrastive loss (Hadsell et al. 2006)
    `tfa.losses.contrastive_loss`
    Args:
        z: hidden vector of shape [bsz, n_features].
        y: ground truth of shape [bsz].
        metric: one of ('euclidean', 'cosine')
    '''
    # compute pair-wise distance matrix
    if metric == 'euclidean':
        D = pdist_euclidean(z)
    elif metric == 'cosine':
        D = 1 - tf.matmul(z, z, transpose_a=False, transpose_b=True)
    # convert squareform matrix to vector form
    d_vec = square_to_vec(D)
    # make contrastive labels
    y_contrasts = get_contrast_batch_labels(y)
    loss = tfa.losses.contrastive_loss(y_contrasts, d_vec, margin=margin)
    # exploding/varnishing gradients on large batch?
    return tf.reduce_mean(loss)


def multiclass_npairs_loss(z, y):
    '''
    Wrapper for the multiclass N-pair loss (Sohn 2016)
    `tfa.losses.npairs_loss`
    Args:
        z: hidden vector of shape [bsz, n_features].
        y: ground truth of shape [bsz].
    '''
    # cosine similarity matrix
    S = tf.matmul(z, z, transpose_a=False, transpose_b=True)
    loss = tfa.losses.npairs_loss(y, S)
    return loss


def triplet_loss(z, y, margin=1.0, kind='hard'):
    '''
    Wrapper for the triplet losses 
    `tfa.losses.triplet_hard_loss` and `tfa.losses.triplet_semihard_loss`
    Args:
        z: hidden vector of shape [bsz, n_features], assumes it is l2-normalized.
        y: ground truth of shape [bsz].    
    '''
    if kind == 'hard':
        loss = tfa.losses.triplet_hard_loss(y, z, margin=margin, soft=False)
    elif kind == 'soft':
        loss = tfa.losses.triplet_hard_loss(y, z, margin=margin, soft=True)
    elif kind == 'semihard':
        loss = tfa.losses.triplet_semihard_loss(y, z, margin=margin)
    return loss


def supervised_nt_xent_loss(z, y, temperature=0.5, base_temperature=0.07):
    '''
    Supervised normalized temperature-scaled cross entropy loss. 
    A variant of Multi-class N-pair Loss from (Sohn 2016)
    Later used in SimCLR (Chen et al. 2020, Khosla et al. 2020).
    Implementation modified from: 
        - https://github.com/google-research/simclr/blob/master/objective.py
        - https://github.com/HobbitLong/SupContrast/blob/master/losses.py
    Args:
        z: hidden vector of shape [bsz, n_features].
        y: ground truth of shape [bsz].
    '''
    batch_size = tf.shape(z)[0]
    contrast_count = 1
    anchor_count = contrast_count
    y = tf.expand_dims(y, -1)

    # mask: contrastive mask of shape [bsz, bsz], mask_{i,j}=1 if sample j
    #     has the same class as sample i. Can be asymmetric.
    mask = tf.cast(tf.equal(y, tf.transpose(y)), tf.float32)
    anchor_dot_contrast = tf.divide(
        tf.matmul(z, tf.transpose(z)),
        temperature
    )
    # for numerical stability
    logits_max = tf.reduce_max(anchor_dot_contrast, axis=1, keepdims=True)
    logits = anchor_dot_contrast - logits_max
    # tile mask
    logits_mask = tf.ones_like(mask) - tf.eye(batch_size)
    mask = mask * logits_mask
    
    # compute log_prob
    exp_logits = tf.exp(logits) * logits_mask

    log_prob = logits - \
        tf.math.log(tf.reduce_sum(exp_logits, axis=1, keepdims=True))

    # compute mean of log-likelihood over positive
    # this may introduce NaNs due to zero division,
    # when a class only has one example in the batch
    mask_sum = tf.reduce_sum(mask, axis=1)
    mean_log_prob_pos = tf.reduce_sum(
        mask * log_prob, axis=1)[mask_sum > 0] / mask_sum[mask_sum > 0]

    # loss
    loss = -(temperature / base_temperature) * mean_log_prob_pos
    # loss = tf.reduce_mean(tf.reshape(loss, [anchor_count, batch_size]))
    loss = tf.reduce_mean(loss)
    return loss

# %%
# Encoder Architecture

def get_simclr():
    base_model = tf.keras.applications.InceptionV3(include_top=False, weights="imagenet", input_shape=INPUT_SHAPE)
    base_model.trainable = False

    for i in range(321, 291):
      base_model.layers[i].trainable = True

    h = base_model.output
    h = GlobalAveragePooling2D()(h)

    features = UnitNormLayer()(h)
    simclr = Model(base_model.inputs, features, name="InceptionV3")

    return simclr

# %%
encoder_optimizer = tf.keras.optimizers.Adam(learning_rate=LR)
model = get_simclr()

# %%
model.summary()

# %%
train_loss_cl = tf.keras.metrics.Mean(name='train_loss')
test_loss_cl = tf.keras.metrics.Mean(name='test_loss')

# %%
@tf.function

def train_step_contrastive(x, y):
    '''
    x: data tensor, shape: (batch_size, data_dim)
    y: data labels, shape: (batch_size, )
    '''
    with tf.GradientTape() as tape:        
        r = model(x, training=True)
        loss = supervised_nt_xent_loss(r, y, temperature=0.05)

    gradients = tape.gradient(loss, model.trainable_variables)
    encoder_optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss_cl(loss)

# %%
@tf.function
def test_step_contrastive(x, y):
    r = model(x, training=False)
    t_loss = supervised_nt_xent_loss(r, y, temperature=0.05)
    test_loss_cl(t_loss)

# %%
#Encoder training
for epoch in range(EPOCHS):
    # Reset the metrics at the start of the next epoch
    train_loss_cl.reset_states()
    test_loss_cl.reset_states()

    for x, y in tqdm(train_ds):
        train_step_contrastive(x, y)

    for x_te, y_te in val_ds:
        test_step_contrastive(x_te, y_te)

    template = 'Epoch {}, Training Loss: {}, Test Loss: {}'
    print(template.format(epoch + 1,train_loss_cl.result(),test_loss_cl.result()))

# %%
suffix = "MulticlassVGG16Loss"
model_dir = "/content/drive/MyDrive/BoneFractureWork/Multiclass/"+suffix+".hdf5"
print(f"{model_dir}")
model.save_weights(filepath = model_dir)

# %%
new_model = get_simclr()
# new_model.load_weights("/content/drive/MyDrive/BoneFractureWork/Loss_minimize/InceptionV3_Elbow_loss_52023_01_21-19_43_20.hdf5")

# %%
classifier_optimizer = tf.keras.optimizers.Adam(learning_rate=LR)

# %%
def classifier_network():

    contrast_model = new_model
    contrast_model.trainable = False
    embedd = contrast_model.output
    features = Dropout(0.5)(embedd)
    features = Dense(512, activation="relu")(features)
    features = Dropout(0.5)(features)
    outputs  = Dense(OUTPUT_SHAPE, activation="softmax")(embedd)

    classifier_model = Model(contrast_model.inputs, outputs, name="Classifier")

    return classifier_model

# %%
classifier = classifier_network()

# %%
classifier.summary()

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_acc = tf.keras.metrics.SparseCategoricalAccuracy(name='train_ACC')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_acc = tf.keras.metrics.SparseCategoricalAccuracy(name='test_ACC')

# %%
cce_loss_obj = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

# %%
@tf.function
# train step for the 2nd stage
def train_step(x, y):
    '''
    x: data tensor, shape: (batch_size, data_dim)
    y: data labels, shape: (batch_size, )
    '''
    with tf.GradientTape() as tape:        
        y_preds = classifier(x, training=True)
        loss = cce_loss_obj(y, y_preds)

    # freeze the encoder, only train the softmax layer
    gradients = tape.gradient(loss, 
                              classifier.trainable_variables) 
    classifier_optimizer.apply_gradients(zip(gradients, 
                                  classifier.trainable_variables))

    train_loss(loss)
    train_acc(y, y_preds)

# %%
@tf.function
def test_step(x, y):
    y_preds = classifier(x, training=False)
    t_loss = cce_loss_obj(y, y_preds)
    test_loss(t_loss)
    test_acc(y, y_preds)

# %%
#classifier training

for epoch in range(EPOCHS):
    # Reset the metrics at the start of the next epoch
    train_loss.reset_states()
    train_acc.reset_states()
    test_loss.reset_states()
    test_acc.reset_states()

    for x, y in tqdm(train_ds):
        train_step(x, y)

    for x_te, y_te in val_ds:
        test_step(x_te, y_te)      
        
    template = 'Epoch {}, Train Loss: {}, Train Acc: {}, Test Loss: {}, Test Acc: {}'
    print(template.format(epoch + 1,train_loss.result(), train_acc.result() * 100,test_loss.result(),test_acc.result() * 100))

# %%
classifier.load_weights("/content/drive/MyDrive/BoneFractureWork/Saved_models/InceptionV3_Elbow_3/2023_01_21-20_21_57.h5")

# %%
predictions = classifier.predict(test_ds)

# %%
predictions

# %%
def get_labels(predictions):
  Y_pred = []
  for i in range(len(predictions)):
    Y_pred.append([predictions[i].argmax()])
  return Y_pred

# %%
Y_pred = get_labels(predictions)

# %%
Y_pred

# %%
Y_test

# %%
def save_model(model, suffix = None):

  model_path = os.path.join("/content/drive/MyDrive/BoneFractureWork/Saved_models/")
  model_dir = model_path + ".h5"

  model.save(filepath = model_dir)

  return model_dir

# %%
save_model(classifier, "InceptionV3_Elbow_3")

# %%
Model_Evaluation( Y_true = Y_test, Y_pred = Y_pred, Labels = Labels, suffix = "InceptionV3_Elbow")
